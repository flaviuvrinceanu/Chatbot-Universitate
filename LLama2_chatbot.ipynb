# %% [markdown]
# <a href="https://colab.research.google.com/github/flaviuvrinceanu/Chatbot-Universitate/blob/main/LLama2_chatbot.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Llama2 Model

# %%
from huggingface_hub import notebook_login
notebook_login()

# %%
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline

# we use a Llama2 model from Hugging Face
model_name = "meta-llama/Llama-2-7b-chat-hf"

# load tokenizer and model
tokenizer = AutoTokenizer.from_pretrained(model_name)
model = AutoModelForCausalLM.from_pretrained(model_name, device_map="auto")

# pipeline creation
generator = pipeline("text-generation", model=model, tokenizer=tokenizer, max_new_tokens=128)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# WARNING:accelerate.big_modeling:Some parameters are on the meta device because they were offloaded to the disk and cpu.
# Device set to use cuda:0

# %% [markdown]
# #Prompts

# %%
prompturi = [
    "What are the main benefits of using chatbots in universities?",
    "Explain what is artificial intelligence in simple terms.",
    "Summarize the importance of data privacy in student services."
]

for i, prompt in enumerate(prompturi, 1):
    result = generator(prompt)
    print(f"\nPrompt {i}:\n{prompt}\nModel Response:\n{result[0]['generated_text']}\n{'-'*60}")
# Out:
# Prompt 1:
# What are the main benefits of using chatbots in universities?
# Model Response:
# What are the main benefits of using chatbots in universities?
# Chatbots are increasingly being used in universities to improve student engagement, retention, and overall university experience. Here are some of the main benefits of using chatbots in universities:
# 1. Personalized support: Chatbots can provide personalized support to students, helping them navigate the university’s systems, courses, and services.
# 2. 24/7 availability: Chatbots can operate around the clock, providing students with instant support and answers to their queries, regardless of the time of day or day of the week.
# 3. Cost-effective:
# ------------------------------------------------------------
#
# Prompt 2:
# Explain what is artificial intelligence in simple terms.
# Model Response:
# Explain what is artificial intelligence in simple terms.
# ...
